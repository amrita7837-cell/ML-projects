# %%
import pandas as pd
imoprt numpy as np
dataset = pd.read_csv(r"C:\Users\kumar\OneDrive\Documents\titanic_data (1).csv")
print(dataset.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
from sklearn.impute import SimpleImputer

# Fill Age with mean
imputer = SimpleImputer(strategy='mean')
dataset[['Age']] = imputer.fit_transform(dataset[['Age']])

# Fill Embarked with most frequent value
dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_4388\521126293.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace=True)

# %%
dataset.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

dataset['Sex'] = le.fit_transform(dataset['Sex'])       # Male/Female → 0/1
dataset['Embarked'] = le.fit_transform(dataset['Embarked'])

# %%
X = dataset.drop('Survived', axis=1)
y = dataset['Survived']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Load dataset
dataset = pd.read_csv(r"C:\Users\kumar\OneDrive\Documents\titanic_data (1).csv")

# Handle missing values
imputer = SimpleImputer(strategy='mean')
dataset[['Age']] = imputer.fit_transform(dataset[['Age']])
dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace=True)

# Drop unnecessary columns
dataset.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# Encoding
le = LabelEncoder()
dataset['Sex'] = le.fit_transform(dataset['Sex'])
dataset['Embarked'] = le.fit_transform(dataset['Embarked'])

# Split
X = dataset.drop('Survived', axis=1)
y = dataset['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_4388\3994851330.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace=True)

# %%
print(dataset.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')
